# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
from matplotlib import pyplot as plt
import numpy as np
warnings.filterwarnings('ignore')
from datetime import timedelta

# %%
path="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_071922_cleaned.csv"
data=pd.read_csv(path)
data.head(5)
# Out:
#                  index  FIT102_Raw_Signal  FIT202_Raw_Signal  \
# 0  2022-07-19 15:07:00             4694.0             9037.5
# 1  2022-07-19 15:07:01             4696.0             9551.0
# 2  2022-07-19 15:07:02             4694.0            10363.5
# 3  2022-07-19 15:07:03             4694.0             8922.5
# 4  2022-07-19 15:07:04             4692.0             9981.0
#
#    LIT101_Raw_Signal  LIT201_Raw_Signal  PIT101_Raw_Signal  PIT102_Raw_Signal  \
# 0            11597.0            12378.5             4425.0        5389.333333
# 1            11613.0            12378.5             4426.5        5391.000000
# 2            11622.0            12377.0             4426.5        5391.500000
# 3            11599.5            12375.0             4424.0        5391.500000
# 4            11608.5            12375.0             4428.0        5391.500000
#
#    PIT201_Raw_Signal  PIT202_Raw_Signal  SI102_Raw_Signal  SI202_Raw_Signal  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13141 entries, 0 to 13140
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              13141 non-null  object
#  1   FIT102_Raw_Signal  13141 non-null  float64
#  2   FIT202_Raw_Signal  13141 non-null  float64
#  3   LIT101_Raw_Signal  13141 non-null  float64
#  4   LIT201_Raw_Signal  13141 non-null  float64
#  5   PIT101_Raw_Signal  13141 non-null  float64
#  6   PIT102_Raw_Signal  13141 non-null  float64
#  7   PIT201_Raw_Signal  13141 non-null  float64
#  8   PIT202_Raw_Signal  13141 non-null  float64
#  9   SI102_Raw_Signal   13141 non-null  float64
#  10  SI202_Raw_Signal   13141 non-null  float64
#  11  event              13141 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 1.2+ MB

# %%
data["event"].value_counts()
# Out:
# normal                    9624
# restoring                 2339
# HV_201                     601
# power                      121
# LCV_103                    121
# LCV_203                     91
# overall_instrument_air      61
# SV_202_A                    61
# SV_101                      61
# Pumps                       61
# Name: event, dtype: int64

# %%
data["anomaly"]=data["event"]!="normal"

# %%
data.head(5)
# Out:
#                  index  FIT102_Raw_Signal  FIT202_Raw_Signal  \
# 0  2022-07-19 15:07:00             4694.0             9037.5
# 1  2022-07-19 15:07:01             4696.0             9551.0
# 2  2022-07-19 15:07:02             4694.0            10363.5
# 3  2022-07-19 15:07:03             4694.0             8922.5
# 4  2022-07-19 15:07:04             4692.0             9981.0
#
#    LIT101_Raw_Signal  LIT201_Raw_Signal  PIT101_Raw_Signal  PIT102_Raw_Signal  \
# 0            11597.0            12378.5             4425.0        5389.333333
# 1            11613.0            12378.5             4426.5        5391.000000
# 2            11622.0            12377.0             4426.5        5391.500000
# 3            11599.5            12375.0             4424.0        5391.500000
# 4            11608.5            12375.0             4428.0        5391.500000
#
#    PIT201_Raw_Signal  PIT202_Raw_Signal  SI102_Raw_Signal  SI202_Raw_Signal  \
# ...

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="anomaly", y="FIT102_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='anomaly', ylabel='FIT102_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="event", y="FIT102_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='event', ylabel='FIT102_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="anomaly", y="FIT202_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='anomaly', ylabel='FIT202_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="event", y="FIT202_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='event', ylabel='FIT202_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="anomaly", y="LIT101_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='anomaly', ylabel='LIT101_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="event", y="LIT101_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='event', ylabel='LIT101_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="anomaly", y="LIT201_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='anomaly', ylabel='LIT201_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="event", y="LIT201_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='event', ylabel='LIT201_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="anomaly", y="PIT101_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='anomaly', ylabel='PIT101_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="event", y="PIT101_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='event', ylabel='PIT101_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="anomaly", y="PIT102_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='anomaly', ylabel='PIT102_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="event", y="PIT102_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='event', ylabel='PIT102_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="anomaly", y="PIT201_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='anomaly', ylabel='PIT201_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="event", y="PIT102_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='event', ylabel='PIT102_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="anomaly", y="PIT202_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='anomaly', ylabel='PIT202_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="event", y="PIT202_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='event', ylabel='PIT202_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="anomaly", y="SI102_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='anomaly', ylabel='SI102_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="event", y="SI102_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='event', ylabel='SI102_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="anomaly", y="SI202_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='anomaly', ylabel='SI202_Raw_Signal'>

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.boxplot(x="event", y="SI102_Raw_Signal", data=data)
# Out:
# <AxesSubplot:xlabel='event', ylabel='SI102_Raw_Signal'>

# %%
features=data[["FIT102_Raw_Signal","FIT202_Raw_Signal","LIT101_Raw_Signal","LIT201_Raw_Signal","PIT101_Raw_Signal","PIT102_Raw_Signal","PIT201_Raw_Signal","PIT202_Raw_Signal","SI102_Raw_Signal","SI202_Raw_Signal"]]
pd.plotting.scatter_matrix(features, figsize=(50, 50))
# Out:
# array([[<AxesSubplot:xlabel='FIT102_Raw_Signal', ylabel='FIT102_Raw_Signal'>,
#         <AxesSubplot:xlabel='FIT202_Raw_Signal', ylabel='FIT102_Raw_Signal'>,
#         <AxesSubplot:xlabel='LIT101_Raw_Signal', ylabel='FIT102_Raw_Signal'>,
#         <AxesSubplot:xlabel='LIT201_Raw_Signal', ylabel='FIT102_Raw_Signal'>,
#         <AxesSubplot:xlabel='PIT101_Raw_Signal', ylabel='FIT102_Raw_Signal'>,
#         <AxesSubplot:xlabel='PIT102_Raw_Signal', ylabel='FIT102_Raw_Signal'>,
#         <AxesSubplot:xlabel='PIT201_Raw_Signal', ylabel='FIT102_Raw_Signal'>,
#         <AxesSubplot:xlabel='PIT202_Raw_Signal', ylabel='FIT102_Raw_Signal'>,
#         <AxesSubplot:xlabel='SI102_Raw_Signal', ylabel='FIT102_Raw_Signal'>,
#         <AxesSubplot:xlabel='SI202_Raw_Signal', ylabel='FIT102_Raw_Signal'>],
#        [<AxesSubplot:xlabel='FIT102_Raw_Signal', ylabel='FIT202_Raw_Signal'>,
#         <AxesSubplot:xlabel='FIT202_Raw_Signal', ylabel='FIT202_Raw_Signal'>,
# ...

# %%
y_train=data["anomaly"]
corrs=features.corrwith(y_train)
corrs.sort_values(ascending=False,key=abs)
# Out:
# FIT202_Raw_Signal   -0.465768
# LIT201_Raw_Signal   -0.405771
# PIT202_Raw_Signal   -0.345115
# SI202_Raw_Signal    -0.342496
# FIT102_Raw_Signal   -0.259963
# LIT101_Raw_Signal   -0.249778
# SI102_Raw_Signal    -0.190436
# PIT102_Raw_Signal   -0.081730
# PIT201_Raw_Signal   -0.036781
# PIT101_Raw_Signal    0.010521
# dtype: float64

# %%
fig, ax=plt.subplots(1,1,figsize=(12,8))
attributes=["FIT102_Raw_Signal","FIT202_Raw_Signal","LIT101_Raw_Signal","LIT201_Raw_Signal","PIT101_Raw_Signal","PIT102_Raw_Signal","PIT201_Raw_Signal","PIT202_Raw_Signal","SI102_Raw_Signal","SI202_Raw_Signal"]
sns.heatmap(data=data[attributes+["anomaly"]].corr())
plt.title("Correlation heatmap of features and anomalies")
# Out:
# Text(0.5, 1.0, 'Correlation heatmap of features and anomalies')

# %%
path_13="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_071322_cleaned.csv"
path_14="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_071422_cleaned.csv"
path_15="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_071522_cleaned.csv"
path_17="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_071722_cleaned.csv"
path_18="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_071822_cleaned.csv"
path_19="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_071922_cleaned.csv"
path_20="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_072022_cleaned.csv"
path_21="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_072122_cleaned.csv"
path_22="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_072222_cleaned.csv"
path_25="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_072522_cleaned.csv"
path_26="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_072622_cleaned.csv"
path_27="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_072722_cleaned.csv"
path_28="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_072822_cleaned.csv"
path_29="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_072922_cleaned.csv"
path_01="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_080122_cleaned.csv"

# %%
data_13=pd.read_csv(path_13)
data_14=pd.read_csv(path_14)
data_15=pd.read_csv(path_15)
data_17=pd.read_csv(path_17)
data_18=pd.read_csv(path_18)
data_19=pd.read_csv(path_19)
data_20=pd.read_csv(path_20)
data_21=pd.read_csv(path_21)
data_22=pd.read_csv(path_22)
data_25=pd.read_csv(path_25)
data_26=pd.read_csv(path_26)
data_27=pd.read_csv(path_27)
data_28=pd.read_csv(path_28)
data_29=pd.read_csv(path_29)
data_01=pd.read_csv(path_01)

# %%
frames = [data_13,data_14,data_15,data_17,data_18,data_19,data_20,data_21,data_22,data_25,data_26,data_27,data_28,data_29,data_01]

# %%
data_all=pd.concat(frames)

# %%
data_all.head(5)
# Out:
#                  index  FIT102_Raw_Signal  FIT202_Raw_Signal  \
# 0  2022-07-13 09:16:00             5458.0            15918.5
# 1  2022-07-13 09:16:01             5460.0            16105.5
# 2  2022-07-13 09:16:02             5462.0            15974.0
# 3  2022-07-13 09:16:03             5462.0            16004.5
# 4  2022-07-13 09:16:04             5471.0            16023.0
#
#    LIT101_Raw_Signal  LIT201_Raw_Signal  PIT101_Raw_Signal  PIT102_Raw_Signal  \
# 0            16089.0            18029.0             4593.0             5749.5
# 1            16082.5            18029.0             4594.0             5750.5
# 2            16075.5            18029.0             4593.5             5750.0
# 3            16088.5            18032.0             4593.0             5748.0
# 4            16088.0            18032.0             4594.0             5749.5
#
#    PIT201_Raw_Signal  PIT202_Raw_Signal  SI102_Raw_Signal  SI202_Raw_Signal  \
# ...

# %%
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 357795 entries, 0 to 24840
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   index              357795 non-null  object
#  1   FIT102_Raw_Signal  357795 non-null  float64
#  2   FIT202_Raw_Signal  357795 non-null  float64
#  3   LIT101_Raw_Signal  357795 non-null  float64
#  4   LIT201_Raw_Signal  357795 non-null  float64
#  5   PIT101_Raw_Signal  357795 non-null  float64
#  6   PIT102_Raw_Signal  357795 non-null  float64
#  7   PIT201_Raw_Signal  357795 non-null  float64
#  8   PIT202_Raw_Signal  357795 non-null  float64
#  9   SI102_Raw_Signal   357795 non-null  float64
#  10  SI202_Raw_Signal   357795 non-null  float64
#  11  event              357795 non-null  object
# dtypes: float64(10), object(2)
# memory usage: 35.5+ MB

# %%
data_all.event.value_counts()
# Out:
# normal                    284164
# restoring                  25035
# period                     19903
# SV_101                      6311
# HV_101                      4544
# SV_201                      3368
# HV_201                      3173
# dos                         2353
# LCV_103                     2290
# LCV_203                     2260
# overall_instrument_air      1672
# power                       1306
# injection                    407
# SV_202_B                     292
# SV_102_A                     181
# Pumps                        152
# SV_101_half                  120
# LCV_202                       81
# SV_202_A                      61
# SV_102_B                      61
# Pumps                         61
# Name: event, dtype: int64

# %%
data_all["anomaly"]=data_all["event"]!="normal"

# %%
y_train=data_all["anomaly"]
features_all=data_all[["FIT102_Raw_Signal","FIT202_Raw_Signal","LIT101_Raw_Signal","LIT201_Raw_Signal","PIT101_Raw_Signal","PIT102_Raw_Signal","PIT201_Raw_Signal","PIT202_Raw_Signal","SI102_Raw_Signal","SI202_Raw_Signal"]]
corrs=features_all.corrwith(y_train)
corrs.sort_values(ascending=False,key=abs)
# Out:
# LIT101_Raw_Signal   -0.278834
# PIT101_Raw_Signal   -0.204231
# LIT201_Raw_Signal   -0.183084
# FIT202_Raw_Signal   -0.160167
# FIT102_Raw_Signal   -0.146581
# SI202_Raw_Signal    -0.142639
# SI102_Raw_Signal    -0.084872
# PIT202_Raw_Signal   -0.076448
# PIT102_Raw_Signal   -0.057807
# PIT201_Raw_Signal    0.023682
# dtype: float64

# %%
fig, ax=plt.subplots(1,1,figsize=(12,8))
attributes=["FIT102_Raw_Signal","FIT202_Raw_Signal","LIT101_Raw_Signal","LIT201_Raw_Signal","PIT101_Raw_Signal","PIT102_Raw_Signal","PIT201_Raw_Signal","PIT202_Raw_Signal","SI102_Raw_Signal","SI202_Raw_Signal"]
sns.heatmap(data=data_all[attributes+["anomaly"]].corr())
plt.title("Correlation heatmap of features and anomalies")
plt.savefig("correlation_features.pdf",bbox_inches='tight')
plt.show()

# %% [markdown]
# Correlation between PIT features:

# %%
fig, ax=plt.subplots(1,1,figsize=(12,8))
attributes=["PIT101_Raw_Signal","PIT102_Raw_Signal","PIT201_Raw_Signal","PIT202_Raw_Signal"]
sns.heatmap(data=data_all[attributes+["anomaly"]].corr())
plt.title("Correlation heatmap of features and anomalies")
plt.savefig("correlation_features.pdf",bbox_inches='tight')
plt.show()
