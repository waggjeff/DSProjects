# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
from matplotlib import pyplot as plt
import numpy as np
warnings.filterwarnings('ignore')
from datetime import timedelta

# %%
import flow_loop_preprocess_XW as process

# %%
path="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_072022.csv"

# %%
data=pd.read_csv(path)

# %%
data.head(5)
# Out:
#       Unnamed: 0 Start time  \
# 0            NaN        NaN
# 1  Variable path        NaN
# 2            NaN        NaN
# 3           Name        NaN
# 4    Description        NaN
#
#                                          7/20/22 8am Stop time  \
# 0                                                NaN       NaN
# 1  \\RWH-201\Test_FlowLoop_Network:RSLinx Enterpr...       NaN
# 2                                                NaN       NaN
# 3                                             FIT102       NaN
# 4                                        Loop 1 Flow       NaN
#
#                                          7/20/22 8pm Unnamed: 5  \
# 0                                                NaN        NaN
# 1  \\RWH-201\Test_FlowLoop_Network:RSLinx Enterpr...        NaN
# 2                                                NaN        NaN
# 3                                  FIT102_Raw_Signal        NaN
# 4                              Loop 1 Flow Raw Value        NaN
#
#                                           Unnamed: 6 Unnamed: 7  \
# 0                                                NaN        NaN
# 1  \\RWH-201\Test_FlowLoop_Network:RSLinx Enterpr...        NaN
# 2                                                NaN        NaN
# 3                                             FIT202        NaN
# 4                                        Loop 2 Flow        NaN
#
#                                           Unnamed: 8 Unnamed: 9  ...  \
# 0                                                NaN        NaN  ...
# 1  \\RWH-201\Test_FlowLoop_Network:RSLinx Enterpr...        NaN  ...
# 2                                                NaN        NaN  ...
# 3                                  FIT202_Raw_Signal        NaN  ...
# 4                              Loop 2 Flow Raw Value        NaN  ...
#
#                                          Unnamed: 32 Unnamed: 33  \
# 0                                                NaN         NaN
# 1  \\RWH-201\Test_FlowLoop_Network:RSLinx Enterpr...         NaN
# 2                                                NaN         NaN
# 3                                  PIT202_Raw_Signal         NaN
# 4                   Pump 2 Outlet Pressure Raw Value         NaN
#
#                                          Unnamed: 34 Unnamed: 35  \
# 0                                                NaN         NaN
# 1  \\RWH-201\Test_FlowLoop_Network:RSLinx Enterpr...         NaN
# 2                                                NaN         NaN
# 3                                              SI102         NaN
# 4                              Pump 1 Speed Feedback         NaN
#
#                                          Unnamed: 36 Unnamed: 37  \
# 0                                                NaN         NaN
# 1  \\RWH-201\Test_FlowLoop_Network:RSLinx Enterpr...         NaN
# 2                                                NaN         NaN
# 3                                   SI102_Raw_Signal         NaN
# 4                    Pump 1 Speed Feedback Raw Value         NaN
#
#                                          Unnamed: 38 Unnamed: 39  \
# 0                                                NaN         NaN
# 1  \\RWH-201\Test_FlowLoop_Network:RSLinx Enterpr...         NaN
# 2                                                NaN         NaN
# 3                                              SI202         NaN
# 4                              Pump 2 Speed Feedback         NaN
#
#                                          Unnamed: 40 Unnamed: 41
# 0                                                NaN         NaN
# 1  \\RWH-201\Test_FlowLoop_Network:RSLinx Enterpr...         NaN
# 2                                                NaN         NaN
# 3                                   SI202_Raw_Signal         NaN
# 4                    Pump 2 Speed Feedback Raw Value         NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# We preprocess the data first:

# %%
data=process.table_formattting(data)

# %%
data.columns
# Out:
# Index(['time_Loop 1 Flow', 'Loop 1 Flow', 'time_Loop 1 Flow Raw Value',
#        'Loop 1 Flow Raw Value', 'time_Loop 2 Flow', 'Loop 2 Flow',
#        'time_Loop 2 Flow Raw Value', 'Loop 2 Flow Raw Value',
#        'time_Tank 1 Level', 'Tank 1 Level', 'time_Tank 1 Level Raw Value',
#        'Tank 1 Level Raw Value', 'time_Tank 2 Level', 'Tank 2 Level',
#        'time_Tank 2 Level Raw Value', 'Tank 2 Level Raw Value',
#        'time_Pump 1 Inlet Pressure', 'Pump 1 Inlet Pressure',
#        'time_Pump 1 Inlet Pressure Raw Value',
#        'Pump 1 Inlet Pressure Raw Value', 'time_Pump 1 Outlet Pressure',
#        'Pump 1 Outlet Pressure', 'time_Pump 1 Outlet Pressure Raw Value',
#        'Pump 1 Outlet Pressure Raw Value', 'time_Pump 2 Inlet Pressure',
#        'Pump 2 Inlet Pressure', 'time_Pump 2 Inlet Pressure Raw Value',
#        'Pump 2 Inlet Pressure Raw Value', 'time_Pump 2 Outlet Pressure',
#        'Pump 2 Outlet Pressure', 'time_Pump 2 Outlet Pressure Raw Value',
#        'Pump 2 Outlet Pressure Raw Value', 'time_Pump 1 Speed Feedback',
#        'Pump 1 Speed Feedback', 'time_Pump 1 Speed Feedback Raw Value',
#        'Pump 1 Speed Feedback Raw Value', 'time_Pump 2 Speed Feedback',
#        'Pump 2 Speed Feedback', 'time_Pump 2 Speed Feedback Raw Value',
#        'Pump 2 Speed Feedback Raw Value'],
#       dtype='object')

# %%
data.head(5)
# Out:
#      time_Loop 1 Flow  Loop 1 Flow time_Loop 1 Flow Raw Value  \
# 0 2022-07-20 09:07:03     4.321875        2022-07-20 08:00:05
# 1 2022-07-20 09:07:04     7.837500        2022-07-20 08:00:24
# 2 2022-07-20 09:07:06    10.284375        2022-07-20 08:00:24
# 3 2022-07-20 09:07:22     7.078125        2022-07-20 08:00:25
# 4 2022-07-20 09:15:19     6.300000        2022-07-20 08:00:37
#
#    Loop 1 Flow Raw Value    time_Loop 2 Flow  Loop 2 Flow  \
# 0                 3997.0 2022-07-20 09:07:03     20.00000
# 1                 3996.0 2022-07-20 09:07:03      3.26000
# 2                 3989.0 2022-07-20 09:07:04      7.94875
# 3                 3997.0 2022-07-20 09:07:04      9.76000
# 4                 3999.0 2022-07-20 09:07:05      7.68750
#
#   time_Loop 2 Flow Raw Value  Loop 2 Flow Raw Value   time_Tank 1 Level  \
# 0        2022-07-20 08:00:09                 3967.0 2022-07-20 09:07:17
# 1        2022-07-20 08:00:10                 3969.0 2022-07-20 09:14:36
# 2        2022-07-20 08:00:12                 3970.0 2022-07-20 09:20:13
# 3        2022-07-20 08:00:12                 3969.0 2022-07-20 09:22:06
# 4        2022-07-20 08:00:15                 3970.0 2022-07-20 09:34:28
#
#    Tank 1 Level  ... time_Pump 2 Outlet Pressure Raw Value  \
# 0     31.879251  ...                   2022-07-20 08:00:10
# 1     31.747501  ...                   2022-07-20 08:00:23
# 2     31.607252  ...                   2022-07-20 08:00:24
# 3     31.683752  ...                   2022-07-20 08:00:28
# 4     31.811253  ...                   2022-07-20 08:00:28
#
#    Pump 2 Outlet Pressure Raw Value time_Pump 1 Speed Feedback  \
# 0                            4129.0        2022-07-20 09:06:51
# 1                            4128.0        2022-07-20 09:06:54
# 2                            4129.0        2022-07-20 09:07:03
# 3                            4128.0        2022-07-20 09:07:04
# 4                            4129.0        2022-07-20 09:07:09
#
#    Pump 1 Speed Feedback time_Pump 1 Speed Feedback Raw Value  \
# 0               1.282500                  2022-07-20 08:00:03
# 1              19.432501                  2022-07-20 08:00:04
# 2              28.001251                  2022-07-20 08:00:05
# 3              25.237501                  2022-07-20 08:00:06
# 4              22.076250                  2022-07-20 08:00:09
#
#    Pump 1 Speed Feedback Raw Value time_Pump 2 Speed Feedback  \
# 0                           4001.0        2022-07-20 09:07:00
# 1                           4000.0        2022-07-20 09:07:04
# 2                           4001.0        2022-07-20 09:07:05
# 3                           4000.0        2022-07-20 09:07:05
# 4                           4001.0        2022-07-20 09:07:06
#
#    Pump 2 Speed Feedback time_Pump 2 Speed Feedback Raw Value  \
# 0               1.443750                  2022-07-20 08:00:05
# 1              22.338751                  2022-07-20 08:00:09
# 2              16.485001                  2022-07-20 08:00:09
# 3              14.808750                  2022-07-20 08:00:14
# 4              15.112500                  2022-07-20 08:00:14
#
#    Pump 2 Speed Feedback Raw Value
# 0                           3998.0
# 1                           3996.0
# 2                           3998.0
# 3                           4001.0
# 4                           3998.0
#
# [5 rows x 40 columns]

# %% [markdown]
# Transform to uniform timestamp:

# %%
for col in data:
    if data[col].dtype == 'O':
        data[col] = pd.to_datetime(data[col])

i = 0
while i <= (data.shape[1] - 2):
    sub_df = process.pull_feature(i, i+1, data)
    sub_df = sub_df.resample('10S').mean()
    if i == 0:
        df = sub_df
    else:
        df = df.join(sub_df, how='outer')
    i += 2
data = df.loc[:, df.columns.str.contains('Raw')]

data.head(5)
# Out:
#                      Loop 1 Flow Raw Value  Loop 2 Flow Raw Value  \
# 2022-07-20 08:00:00                 3997.0            3967.000000
# 2022-07-20 08:00:10                    NaN            3969.285714
# 2022-07-20 08:00:20                 3994.0            3968.285714
# 2022-07-20 08:00:30                 3998.0            3968.428571
# 2022-07-20 08:00:40                 3997.5            3968.875000
#
#                      Tank 1 Level Raw Value  Tank 2 Level Raw Value  \
# 2022-07-20 08:00:00                     NaN                 13804.5
# 2022-07-20 08:00:10                     NaN                 13804.0
# 2022-07-20 08:00:20                     NaN                 13803.8
# 2022-07-20 08:00:30                     NaN                 13804.5
# 2022-07-20 08:00:40                     NaN                 13804.5
#
#                      Pump 1 Inlet Pressure Raw Value  \
# 2022-07-20 08:00:00                      4424.600000
# 2022-07-20 08:00:10                      4424.666667
# 2022-07-20 08:00:20                      4424.818182
# 2022-07-20 08:00:30                      4424.923077
# 2022-07-20 08:00:40                      4425.285714
#
#                      Pump 1 Outlet Pressure Raw Value  \
# 2022-07-20 08:00:00                       5069.000000
# 2022-07-20 08:00:10                       5068.363636
# 2022-07-20 08:00:20                       5068.900000
# 2022-07-20 08:00:30                       5069.272727
# 2022-07-20 08:00:40                       5068.500000
#
#                      Pump 2 Inlet Pressure Raw Value  \
# 2022-07-20 08:00:00                           4369.0
# 2022-07-20 08:00:10                           4368.5
# 2022-07-20 08:00:20                              NaN
# 2022-07-20 08:00:30                              NaN
# 2022-07-20 08:00:40                           4368.5
#
#                      Pump 2 Outlet Pressure Raw Value  \
# 2022-07-20 08:00:00                               NaN
# 2022-07-20 08:00:10                            4129.0
# 2022-07-20 08:00:20                            4128.5
# 2022-07-20 08:00:30                            4128.5
# 2022-07-20 08:00:40                               NaN
#
#                      Pump 1 Speed Feedback Raw Value  \
# 2022-07-20 08:00:00                      4000.500000
# 2022-07-20 08:00:10                      3999.888889
# 2022-07-20 08:00:20                      4000.900000
# 2022-07-20 08:00:30                      4000.333333
# 2022-07-20 08:00:40                      3999.750000
#
#                      Pump 2 Speed Feedback Raw Value
# 2022-07-20 08:00:00                      3997.333333
# 2022-07-20 08:00:10                      3999.000000
# 2022-07-20 08:00:20                      3999.250000
# 2022-07-20 08:00:30                      3999.000000
# 2022-07-20 08:00:40                      3998.250000

# %%
fig, ax=plt.subplots(1,1,figsize=(20,6))
sns.lineplot(x=data.index,y="Loop 1 Flow Raw Value",data=data,label="Loop 1 Flow")
sns.lineplot(x=data.index,y="Loop 2 Flow Raw Value",data=data,label="Loop 2 Flow")
# Out:
# <AxesSubplot:ylabel='Loop 1 Flow Raw Value'>

# %% [markdown]
# Next, we plot an isolated anomaly.

# %%
#Xifan`s plotting script:
def anomalie_detection(begin, end, event_name):
    event_begin = pd.to_datetime('2022-07-20 ' + begin)
    event_end = pd.to_datetime('2022-07-20 ' + end)
    pre_time = event_begin - timedelta(minutes=2)
    aft_time = event_end + timedelta(minutes=2)

    sub_df = data[pre_time : aft_time]
    fig, ax = plt.subplots(figsize=(18,8))
    ax.plot(sub_df,'o-', label=data.columns)
    ax.vlines([event_begin, event_end], 2, 18000, colors='black', linestyles='dashed' )
    ax.set_yscale('log')
    ax.legend()
    ax.set_title(f'{event_name}, begin: {begin}, end: {end}', fontsize=14)
    plt.show()

# %%
event_dic = {
    'SV_102_A_air_close_open': ['10:48:00', '10:51:00'],
    'SV_202_A_air_close_open': ['11:04:00', '11:07:00'],
    'SV_102_B_air_close_open': ['11:28:00', '11:31:00'],
    'SV_202_B_air_close_open': ['11:41:00', '11:42:00'],
    "LCV_203_air_close_open": ['12:19:00', '12:23:00'],
    "LCV_103_air_close_open": ['12:47:00', '12:57:00'],
     'SV_201_air_close_open': ['14:51:00', '14:56:00'],
    'SV_101_air_close_open': ['15:05:00', '15:08:00'],
    'overall_instrument_air': ['15:40:00', '15:40:00'],
}

# %%
anomalie_detection(event_dic['SV_102_A_air_close_open'][0], event_dic['SV_102_A_air_close_open'][1], 'SV_102_A_air_close_open')

# %% [markdown]
# In order to compare this with the same kind of anomoly, the load the data for an additional day (the 19th of July):

# %%
path2="../../data/Rockwell_Flow_Loop_Data/Flow_Loop_Data_071922.csv"
data2=pd.read_csv(path2)
data2=process.table_formattting(data2)
data2.head(5)
# Out:
#      time_Loop 1 Flow  Loop 1 Flow time_Loop 1 Flow Raw Value  \
# 0 2022-07-19 10:08:58     8.990625        2022-07-19 08:00:05
# 1 2022-07-19 10:08:59    10.040626        2022-07-19 08:00:17
# 2 2022-07-19 10:09:20     6.637500        2022-07-19 08:00:18
# 3 2022-07-19 15:12:00     6.225000        2022-07-19 08:00:24
# 4 2022-07-19 15:12:03     1.828125        2022-07-19 08:00:24
#
#    Loop 1 Flow Raw Value    time_Loop 2 Flow  Loop 2 Flow  \
# 0                 3997.0 2022-07-19 10:08:51     7.510001
# 1                 3995.0 2022-07-19 10:08:52     8.523750
# 2                 3997.0 2022-07-19 10:08:53     5.566250
# 3                 3995.0 2022-07-19 10:08:54     5.438750
# 4                 3997.0 2022-07-19 10:08:55     8.445001
#
#   time_Loop 2 Flow Raw Value  Loop 2 Flow Raw Value   time_Tank 1 Level  \
# 0        2022-07-19 08:00:20                 3971.0 2022-07-19 10:10:21
# 1        2022-07-19 08:00:25                 3970.0 2022-07-19 10:26:27
# 2        2022-07-19 08:00:25                 3971.0 2022-07-19 10:29:51
# 3        2022-07-19 08:00:34                 3972.0 2022-07-19 10:33:07
# 4        2022-07-19 08:00:35                 3971.0 2022-07-19 10:39:44
#
#    Tank 1 Level  ... time_Pump 2 Outlet Pressure Raw Value  \
# 0     27.684502  ...                   2022-07-19 08:00:09
# 1     27.523001  ...                   2022-07-19 08:00:09
# 2     27.497501  ...                   2022-07-19 08:00:11
# 3     27.667501  ...                   2022-07-19 08:00:13
# 4     27.518751  ...                   2022-07-19 08:00:13
#
#    Pump 2 Outlet Pressure Raw Value time_Pump 1 Speed Feedback  \
# 0                            4162.0        2022-07-19 10:08:48
# 1                            4163.0        2022-07-19 10:08:48
# 2                            4162.0        2022-07-19 10:08:56
# 3                            4163.0        2022-07-19 10:08:57
# 4                            4162.0        2022-07-19 10:08:58
#
#    Pump 1 Speed Feedback time_Pump 1 Speed Feedback Raw Value  \
# 0              18.157501                  2022-07-19 08:00:01
# 1              20.272501                  2022-07-19 08:00:02
# 2              27.345001                  2022-07-19 08:00:03
# 3              27.322500                  2022-07-19 08:00:04
# 4              24.712502                  2022-07-19 08:00:04
#
#    Pump 1 Speed Feedback Raw Value time_Pump 2 Speed Feedback  \
# 0                           4001.0        2022-07-19 10:08:48
# 1                           3999.0        2022-07-19 10:08:51
# 2                           4001.0        2022-07-19 10:08:52
# 3                           4000.0        2022-07-19 10:08:53
# 4                           4001.0        2022-07-19 10:08:54
#
#    Pump 2 Speed Feedback time_Pump 2 Speed Feedback Raw Value  \
# 0               1.275000                  2022-07-19 08:00:01
# 1              22.151251                  2022-07-19 08:00:02
# 2              16.395000                  2022-07-19 08:00:04
# 3              15.502501                  2022-07-19 08:00:04
# 4              24.108751                  2022-07-19 08:00:05
#
#    Pump 2 Speed Feedback Raw Value
# 0                           3997.0
# 1                           3998.0
# 2                           3997.0
# 3                           3998.0
# 4                           3996.0
#
# [5 rows x 40 columns]

# %%
for col in data2:
    if data2[col].dtype == 'O':
        data2[col] = pd.to_datetime(data2[col])

i = 0
while i <= (data2.shape[1] - 2):
    sub_df2 = process.pull_feature(i, i+1, data2)
    sub_df2 = sub_df2.resample('10S').mean()
    if i == 0:
        df2 = sub_df2
    else:
        df2 = df2.join(sub_df2, how='outer')
    i += 2
data2 = df2.loc[:, df2.columns.str.contains('Raw')]

data2.head(5)
# Out:
#                      Loop 1 Flow Raw Value  Loop 2 Flow Raw Value  \
# 2022-07-19 08:00:00                 3997.0                    NaN
# 2022-07-19 08:00:10                 3996.0                    NaN
# 2022-07-19 08:00:20                 3996.0            3970.666667
# 2022-07-19 08:00:30                    NaN            3971.500000
# 2022-07-19 08:00:40                 3996.5                    NaN
#
#                      Tank 1 Level Raw Value  Tank 2 Level Raw Value  \
# 2022-07-19 08:00:00            10692.642857            15254.166667
# 2022-07-19 08:00:10            10694.777778            15254.500000
# 2022-07-19 08:00:20            10694.941176            15254.000000
# 2022-07-19 08:00:30            10694.687500            15253.500000
# 2022-07-19 08:00:40            10693.100000            15253.400000
#
#                      Pump 1 Inlet Pressure Raw Value  \
# 2022-07-19 08:00:00                      4382.500000
# 2022-07-19 08:00:10                      4382.466667
# 2022-07-19 08:00:20                      4382.692308
# 2022-07-19 08:00:30                      4382.800000
# 2022-07-19 08:00:40                      4382.250000
#
#                      Pump 1 Outlet Pressure Raw Value  \
# 2022-07-19 08:00:00                       5012.250000
# 2022-07-19 08:00:10                       5012.222222
# 2022-07-19 08:00:20                       5011.500000
# 2022-07-19 08:00:30                       5012.000000
# 2022-07-19 08:00:40                       5012.714286
#
#                      Pump 2 Inlet Pressure Raw Value  \
# 2022-07-19 08:00:00                      4425.500000
# 2022-07-19 08:00:10                      4425.500000
# 2022-07-19 08:00:20                      4425.555556
# 2022-07-19 08:00:30                      4425.500000
# 2022-07-19 08:00:40                      4425.500000
#
#                      Pump 2 Outlet Pressure Raw Value  \
# 2022-07-19 08:00:00                            4162.5
# 2022-07-19 08:00:10                            4162.4
# 2022-07-19 08:00:20                            4162.5
# 2022-07-19 08:00:30                            4162.5
# 2022-07-19 08:00:40                            4162.6
#
#                      Pump 1 Speed Feedback Raw Value  \
# 2022-07-19 08:00:00                      4000.285714
# 2022-07-19 08:00:10                      4000.500000
# 2022-07-19 08:00:20                      3999.000000
# 2022-07-19 08:00:30                      4001.500000
# 2022-07-19 08:00:40                      4000.833333
#
#                      Pump 2 Speed Feedback Raw Value
# 2022-07-19 08:00:00                      3997.333333
# 2022-07-19 08:00:10                      3996.500000
# 2022-07-19 08:00:20                      3999.500000
# 2022-07-19 08:00:30                      3999.000000
# 2022-07-19 08:00:40                      3999.500000

# %%
#Xifan`s plotting script:
def anomalie_detection2(begin, end, event_name):
    event_begin = pd.to_datetime('2022-07-19 ' + begin)
    event_end = pd.to_datetime('2022-07-19 ' + end)
    pre_time = event_begin - timedelta(minutes=2)
    aft_time = event_end + timedelta(minutes=2)

    sub_df2 = data2[pre_time : aft_time]
    fig, ax = plt.subplots(figsize=(18,8))
    ax.plot(sub_df2,'o-', label=data2.columns)
    ax.vlines([event_begin, event_end], 2, 18000, colors='black', linestyles='dashed' )
    ax.set_yscale('log')
    ax.legend()
    ax.set_title(f'{event_name}, begin: {begin}, end: {end}', fontsize=14)
    plt.show()

# %%
event_dic2 = {
    "power":["15:12:00","15:16:00"],
    'overall_instrument_air': ['15:39:00', '15:41:00'],
    'SV_202_A_air_close_open': ['15:44:00', '15:45:00'],
    'SV_102_A_air_close_open': ['15:47:00', '15:48:00'],
    "LCV_203_air_close_open": ['16:12:00', '16:16:00'],
    "LCV_103_air_close_open": ['16:32:00', '16:38:00'],
    'SV_201_air_close_open': ['17:00:00', '17:00:00'],
    'SV_101_air_close_open': ['17:28:00', '17:31:00'],
    'HV_201_air_close_open': ['17:57:00', '18:26:00'],
    "Pumps":["18:30:00","18:36:00"],
}

# %%
anomalie_detection2(event_dic2['SV_102_A_air_close_open'][0], event_dic2['SV_102_A_air_close_open'][1], 'SV_102_A_air_close_open')

# %% [markdown]
# Similarly, we can look at other anomalies:

# %%
anomalie_detection(event_dic['SV_202_A_air_close_open'][0], event_dic['SV_202_A_air_close_open'][1], 'SV_202_A_air_close_open')
anomalie_detection2(event_dic2['SV_202_A_air_close_open'][0], event_dic2['SV_202_A_air_close_open'][1], 'SV_202_A_air_close_open')

# %%
anomalie_detection(event_dic['overall_instrument_air'][0], event_dic['overall_instrument_air'][1], 'overall_instrument_air')
anomalie_detection2(event_dic2['overall_instrument_air'][0], event_dic2['overall_instrument_air'][1], 'overall_instrument_air')

# %%
anomalie_detection(event_dic['LCV_203_air_close_open'][0], event_dic['LCV_203_air_close_open'][1], 'LCV_203_air_close_open')
anomalie_detection2(event_dic2['LCV_203_air_close_open'][0], event_dic2['LCV_203_air_close_open'][1], 'LCV_203_air_close_open')

# %%
anomalie_detection(event_dic['LCV_103_air_close_open'][0], event_dic['LCV_103_air_close_open'][1], 'LCV_103_air_close_open')
anomalie_detection2(event_dic2['LCV_103_air_close_open'][0], event_dic2['LCV_103_air_close_open'][1], 'LCV_103_air_close_open')

# %%
anomalie_detection(event_dic['SV_201_air_close_open'][0], event_dic['SV_201_air_close_open'][1], 'SV_201_air_close_open')
anomalie_detection2(event_dic2['SV_201_air_close_open'][0], event_dic2['SV_201_air_close_open'][1], 'SV_201_air_close_open')

# %%
anomalie_detection(event_dic['SV_101_air_close_open'][0], event_dic['SV_101_air_close_open'][1], 'SV_101_air_close_open')
anomalie_detection2(event_dic2['SV_101_air_close_open'][0], event_dic2['SV_101_air_close_open'][1], 'SV_101_air_close_open')
