# %% [markdown]
# ## Script to do some exploratory data analysis of Flow Data

# %%
#v1.1 modified to handle new csv files provided by EPRI (July 28, 2022)
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# read the data into a dataframe from the csv files and do some reformatting to get rid of blank rows and columns
df1 = pd.read_csv('Flow_Loop_Data_071322.csv',header=[4])
df1 = df1.iloc[: , 1:] # first column is mostly blank
df1 = df1.iloc[3:,:] # after column header, there are some blank or non-numeric columns

df2 = pd.read_csv('Flow_Loop_Data_071422.csv',header=[4])
df2 = df2.iloc[: , 1:] 
df2 = df2.iloc[3:,:] 

df3 = pd.read_csv('Flow_Loop_Data_071522.csv',header=[4])
df3 = df3.iloc[: , 1:] 
df3 = df3.iloc[3:,:] 

df4 = pd.read_csv('Flow_Loop_Data_071722.csv',header=[4])
df4 = df4.iloc[: , 1:] 
df4 = df4.iloc[3:,:] 

df5 = pd.read_csv('Flow_Loop_Data_071822.csv',header=[4])
df5 = df5.iloc[: , 1:] 
df5 = df5.iloc[3:,:] 

df6 = pd.read_csv('Flow_Loop_Data_071922.csv',header=[4])
df6 = df6.iloc[: , 1:] 
df6 = df6.iloc[3:,:] 

df7 = pd.read_csv('Flow_Loop_Data_072022.csv',header=[4])
df7 = df7.iloc[: , 1:] 
df7 = df7.iloc[3:,:] 

df8 = pd.read_csv('Flow_Loop_Data_072122.csv',header=[4])
df8 = df8.iloc[: , 1:] 
df8 = df8.iloc[3:,:] 

df9 = pd.read_csv('Flow_Loop_Data_072222.csv',header=[4])
df9 = df9.iloc[: , 1:] 
df9 = df9.iloc[3:,:] 

df10 = pd.read_csv('Flow_Loop_Data_072522.csv',header=[4])
df10 = df7.iloc[: , 1:] 
df10 = df7.iloc[3:,:]

# %%
# every second column should be treated as a series of time stamps, so change these column names 
for i in range(0,df1.columns.size-1,2):
    df1.rename(columns={df1.columns[i]:'Time_'+df1.columns[i+1]},inplace=True)
    time_col = df1.columns[i]
    data_col = df1.columns[i+1]
    #print(time_col,data_col)
    df1[time_col] = df1[time_col].dropna()
    df1[data_col] = df1[data_col].dropna()
    df1[time_col] = pd.to_datetime(df1[time_col],errors='coerce')
    df1[data_col] = pd.to_numeric(df1[data_col],errors='coerce')
    
for i in range(0,df2.columns.size-1,2):
    df2.rename(columns={df2.columns[i]:'Time_'+df2.columns[i+1]},inplace=True)
    time_col = df2.columns[i]
    data_col = df2.columns[i+1]
    #print(time_col,data_col)
    df2[time_col] = df2[time_col].dropna()
    df2[data_col] = df2[data_col].dropna()
    df2[time_col] = pd.to_datetime(df2[time_col],errors='coerce')
    df2[data_col] = pd.to_numeric(df2[data_col],errors='coerce')
    
for i in range(0,df3.columns.size-1,2):
    df3.rename(columns={df3.columns[i]:'Time_'+df3.columns[i+1]},inplace=True)
    time_col = df3.columns[i]
    data_col = df3.columns[i+1]
    #print(time_col,data_col)
    df3[time_col] = df3[time_col].dropna()
    df3[data_col] = df3[data_col].dropna()
    df3[time_col] = pd.to_datetime(df3[time_col],errors='coerce')
    df3[data_col] = pd.to_numeric(df3[data_col],errors='coerce')
    
for i in range(0,df4.columns.size-1,2):
    df4.rename(columns={df4.columns[i]:'Time_'+df4.columns[i+1]},inplace=True)
    time_col = df4.columns[i]
    data_col = df4.columns[i+1]
    #print(time_col,data_col)
    df4[time_col] = df4[time_col].dropna()
    df4[data_col] = df4[data_col].dropna()
    df4[time_col] = pd.to_datetime(df4[time_col],errors='coerce')
    df4[data_col] = pd.to_numeric(df4[data_col],errors='coerce')
    
for i in range(0,df5.columns.size-1,2):
    df5.rename(columns={df5.columns[i]:'Time_'+df5.columns[i+1]},inplace=True)
    time_col = df5.columns[i]
    data_col = df5.columns[i+1]
    #print(time_col,data_col)
    df5[time_col] = df5[time_col].dropna()
    df5[data_col] = df5[data_col].dropna()
    df5[time_col] = pd.to_datetime(df5[time_col],errors='coerce')
    df5[data_col] = pd.to_numeric(df5[data_col],errors='coerce')
    
for i in range(0,df6.columns.size-1,2):
    df6.rename(columns={df3.columns[i]:'Time_'+df6.columns[i+1]},inplace=True)
    time_col = df6.columns[i]
    data_col = df6.columns[i+1]
    #print(time_col,data_col)
    df6[time_col] = df6[time_col].dropna()
    df6[data_col] = df6[data_col].dropna()
    df6[time_col] = pd.to_datetime(df6[time_col],errors='coerce')
    df6[data_col] = pd.to_numeric(df6[data_col],errors='coerce')
    
for i in range(0,df7.columns.size-1,2):
    df7.rename(columns={df7.columns[i]:'Time_'+df7.columns[i+1]},inplace=True)
    time_col = df7.columns[i]
    data_col = df7.columns[i+1]
    #print(time_col,data_col)
    df7[time_col] = df7[time_col].dropna()
    df7[data_col] = df7[data_col].dropna()
    df7[time_col] = pd.to_datetime(df7[time_col],errors='coerce')
    df7[data_col] = pd.to_numeric(df7[data_col],errors='coerce')
    
for i in range(0,df8.columns.size-1,2):
    df8.rename(columns={df8.columns[i]:'Time_'+df8.columns[i+1]},inplace=True)
    time_col = df8.columns[i]
    data_col = df8.columns[i+1]
    #print(time_col,data_col)
    df8[time_col] = df8[time_col].dropna()
    df8[data_col] = df8[data_col].dropna()
    df8[time_col] = pd.to_datetime(df8[time_col],errors='coerce')
    df8[data_col] = pd.to_numeric(df8[data_col],errors='coerce')
    
for i in range(0,df9.columns.size-1,2):
    df9.rename(columns={df9.columns[i]:'Time_'+df9.columns[i+1]},inplace=True)
    time_col = df9.columns[i]
    data_col = df9.columns[i+1]
    #print(time_col,data_col)
    df9[time_col] = df9[time_col].dropna()
    df9[data_col] = df9[data_col].dropna()
    df9[time_col] = pd.to_datetime(df9[time_col],errors='coerce')
    df9[data_col] = pd.to_numeric(df9[data_col],errors='coerce')
    
for i in range(0,df10.columns.size-1,2):
    df10.rename(columns={df10.columns[i]:'Time_'+df10.columns[i+1]},inplace=True)
    time_col = df10.columns[i]
    data_col = df10.columns[i+1]
    #print(time_col,data_col)
    df10[time_col] = df10[time_col].dropna()
    df10[data_col] = df10[data_col].dropna()
    df10[time_col] = pd.to_datetime(df10[time_col],errors='coerce')
    df10[data_col] = pd.to_numeric(df10[data_col],errors='coerce')
# Out:
# /Users/j.wagg/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# <ipython-input-152-5fc2ee385255>:97: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df10[time_col] = df10[time_col].dropna()
# <ipython-input-152-5fc2ee385255>:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# Now calculate some basic stats and plot the time series
for i in range(0,df1.columns.size-1,2):
    print(df1.columns[i+1])
    print(df1[df1.columns[i+1]].describe())
    df1.plot(x=df1.columns[i],y=df1.columns[i+1], marker="o",linestyle='None') 
    plt.show()
    
for i in range(0,df2.columns.size-1,2):
    print(df2.columns[i+1])
    print(df2[df2.columns[i+1]].describe())
    df2.plot(x=df2.columns[i],y=df2.columns[i+1], marker="o",linestyle='None') 
    plt.show()
    
for i in range(0,df3.columns.size-1,2):
    print(df3.columns[i+1])
    print(df3[df3.columns[i+1]].describe())
    df3.plot(x=df3.columns[i],y=df3.columns[i+1], marker="o",linestyle='None') 
    plt.show()

for i in range(0,df4.columns.size-1,2):
    print(df4.columns[i+1])
    print(df4[df4.columns[i+1]].describe())
    df4.plot(x=df3.columns[i],y=df4.columns[i+1], marker="o",linestyle='None') 
    plt.show()
    
for i in range(0,df5.columns.size-1,2):
    print(df5.columns[i+1])
    print(df5[df5.columns[i+1]].describe())
    df5.plot(x=df5.columns[i],y=df5.columns[i+1], marker="o",linestyle='None') 
    plt.show()
    
for i in range(0,df6.columns.size-1,2):
    print(df6.columns[i+1])
    print(df6[df6.columns[i+1]].describe())
    df6.plot(x=df6.columns[i],y=df6.columns[i+1], marker="o",linestyle='None') 
    plt.show()

for i in range(0,df7.columns.size-1,2):
    print(df7.columns[i+1])
    print(df7[df7.columns[i+1]].describe())
    df7.plot(x=df7.columns[i],y=df7.columns[i+1], marker="o",linestyle='None') 
    plt.show()
    
for i in range(0,df8.columns.size-1,2):
    print(df8.columns[i+1])
    print(df8[df8.columns[i+1]].describe())
    df3.plot(x=df8.columns[i],y=df8.columns[i+1], marker="o",linestyle='None') 
    plt.show()
    
for i in range(0,df9.columns.size-1,2):
    print(df9.columns[i+1])
    print(df9[df9.columns[i+1]].describe())
    df9.plot(x=df9.columns[i],y=df9.columns[i+1], marker="o",linestyle='None') 
    plt.show()
    
for i in range(0,df10.columns.size-1,2):
    print(df10.columns[i+1])
    print(df10[df10.columns[i+1]].describe())
    df10.plot(x=df10.columns[i],y=df10.columns[i+1], marker="o",linestyle='None') 
    plt.show()
# Out:
# FIT102
# count    20.000000
# mean     10.435313
# std       5.161834
# min      -0.056250
# 25%       9.274219
# 50%      13.396876
# 75%      13.781250
# max      13.875001
# Name: FIT102, dtype: float64
# FIT102_Raw_Signal
# count    41810.000000
# mean      5319.787682
# std        424.428708
# min       3989.000000
# 25%       5447.000000
# 50%       5454.000000
# 75%       5461.000000
# max       5495.000000
# Name: FIT102_Raw_Signal, dtype: float64
# FIT202
# count    47.000000
# mean     13.512926
# std       3.451239
# min       0.002500
# 25%      13.549376
# 50%      14.878751
# 75%      15.049376
# max      15.243752
# Name: FIT202, dtype: float64
# FIT202_Raw_Signal
# count    62503.000000
# mean     14804.108187
# std       3596.434822
# min       3968.000000
# 25%      15943.000000
# 50%      15991.000000
# 75%      16034.000000
# max      16295.000000
# Name: FIT202_Raw_Signal, dtype: float64
# LIT101
# count     6.000000
# mean     51.004252
# std       0.266594
# ...
