# %% [markdown]
# ## Application of Random Forest to Flow Data data stream
#
# This code is based on the random forest ipython notebook generated by KJ for the October, 2021 analysis of EPRI Flow Data. The version here is meant to process the flow loop data and look for the changes to the data stream produced by physical anomalies, as indicated by the notebook provided by Lea Boche and Christina Lawson (EPRI). This version reads in pre-defined testing and training datasets and analyses the binary (normal/mechanical anomaly) scenarios (v1.6).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt


from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble  import RandomForestClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import roc_auc_score, mean_squared_error, r2_score, accuracy_score, confusion_matrix, classification_report, plot_confusion_matrix, make_scorer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit
from sklearn import tree
from sklearn.preprocessing import StandardScaler


import sys
sys.path.append('/Users/j.wagg/DataScience/S2DS/EPRI/NewData2022/Logs')
from lablog_parser import *
from custom_metric import *

pd.set_option("display.max.columns", None)

# %%
# reading in the flow loop data training sample 
flow_test = pd.read_csv("test_wternary.csv")
flow_train = pd.read_csv("train_wternary.csv")
flow_test.keys()
# Out:
# Index(['Unnamed: 0', 'max_FIT102_Raw_Signal', 'min_FIT102_Raw_Signal',
#        'mean_FIT102_Raw_Signal', 'std_FIT102_Raw_Signal',
#        'max_FIT202_Raw_Signal', 'min_FIT202_Raw_Signal',
#        'mean_FIT202_Raw_Signal', 'std_FIT202_Raw_Signal',
#        'max_LIT101_Raw_Signal', 'min_LIT101_Raw_Signal',
#        'mean_LIT101_Raw_Signal', 'std_LIT101_Raw_Signal',
#        'max_LIT201_Raw_Signal', 'min_LIT201_Raw_Signal',
#        'mean_LIT201_Raw_Signal', 'std_LIT201_Raw_Signal',
#        'max_PIT101_Raw_Signal', 'min_PIT101_Raw_Signal',
#        'mean_PIT101_Raw_Signal', 'std_PIT101_Raw_Signal',
#        'max_PIT102_Raw_Signal', 'min_PIT102_Raw_Signal',
#        'mean_PIT102_Raw_Signal', 'std_PIT102_Raw_Signal',
#        'max_PIT201_Raw_Signal', 'min_PIT201_Raw_Signal',
#        'mean_PIT201_Raw_Signal', 'std_PIT201_Raw_Signal',
#        'max_PIT202_Raw_Signal', 'min_PIT202_Raw_Signal',
#        'mean_PIT202_Raw_Signal', 'std_PIT202_Raw_Signal',
#        'max_SI102_Raw_Signal', 'min_SI102_Raw_Signal', 'mean_SI102_Raw_Signal',
#        'std_SI102_Raw_Signal', 'max_SI202_Raw_Signal', 'min_SI202_Raw_Signal',
#        'mean_SI202_Raw_Signal', 'std_SI202_Raw_Signal', 'na_FIT102_Raw_Signal',
#        'na_FIT202_Raw_Signal', 'na_LIT101_Raw_Signal', 'na_LIT201_Raw_Signal',
#        'na_PIT101_Raw_Signal', 'na_PIT102_Raw_Signal', 'na_PIT201_Raw_Signal',
#        'na_PIT202_Raw_Signal', 'na_SI102_Raw_Signal', 'na_SI202_Raw_Signal',
#        'event', 'binary', 'ternary'],
#       dtype='object')

# %%
# add a new column to the data frame so that anomalies appear as binary 1 yes/0 no anomaly
# we can then use this for the Neural Network (just convert the 'label' column)
flow_test['tern_anomaly'] = 0
flow_train['tern_anomaly'] = 0
flow_test['bin_anomaly'] = 0
flow_train['bin_anomaly'] = 0

for index in flow_test.index:
    if flow_test['ternary'][index] == 'normal':
        flow_test.at[index,'tern_anomaly'] = 0
    if flow_test['ternary'][index] == 'mechanical':
        flow_test.at[index,'tern_anomaly'] = 1
    if flow_test['ternary'][index] == 'cyber':
        flow_test.at[index,'tern_anomaly'] = 2   
        
for index in flow_train.index:
    if flow_train['ternary'][index] == 'normal':
        flow_train.at[index,'tern_anomaly'] = 0
    if flow_train['ternary'][index] == 'mechanical':
        flow_train.at[index,'tern_anomaly'] = 1
    if flow_train['ternary'][index] == 'cyber':
        flow_train.at[index,'tern_anomaly'] = 2   

for index in flow_test.index:
    if flow_test['binary'][index] != 'normal':
        flow_test.at[index,'bin_anomaly'] = 1 

for index in flow_train.index:
    if flow_train['binary'][index] != 'normal':
        flow_train.at[index,'bin_anomaly'] = 1

# %% [markdown]
# ## Random Forest binary approach to classification of anomalies

# %%
drop_list = ['Unnamed: 0','event','binary','ternary','tern_anomaly']
             #,'std_FIT202_Raw_Signal','min_SI102_Raw_Signal','std_PIT102_Raw_Signal',
             #'min_LIT101_Raw_Signal','std_PIT101_Raw_Signal','max_SI102_Raw_Signal','max_PIT101_Raw_Signal',
             #'std_LIT101_Raw_Signal','mean_PIT202_Raw_Signal','std_FIT102_Raw_Signal','max_PIT202_Raw_Signal',
             #'mean_FIT202_Raw_Signal','min_PIT202_Raw_Signal','max_PIT102_Raw_Signal','mean_PIT201_Raw_Signal',
             #'mean_PIT102_Raw_Signal','min_PIT102_Raw_Signal','min_FIT102_Raw_Signal','min_PIT201_Raw_Signal',
             #'mean_SI102_Raw_Signal','max_LIT101_Raw_Signal','mean_FIT102_Raw_Signal','mean_SI202_Raw_Signal',
             #'max_FIT102_Raw_Signal','min_PIT101_Raw_Signal']

value = 'bin_anomaly'
print(flow_train['bin_anomaly'].describe())
# Out:
# count    11373.000000
# mean         0.192034
# std          0.393917
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: bin_anomaly, dtype: float64

# %%
# Begin with binary classification approach

scaler = StandardScaler()  
#drop the columns we don't need
df1 = flow_train.drop(drop_list, axis=1)
df2 = flow_test.drop(drop_list, axis=1)

print(df1.head())
    
#define features and value
X = df1.drop(value, axis=1)
y = df1[value]
    
    
#create train and test datasets
#X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.20, random_state = 100)
X_train = df1.drop(value, axis=1)
y_train = df1[value]
X_val = df2.drop(value, axis=1)
y_val = df2[value]

#train the model
model = RandomForestClassifier(random_state = 100)
    
model.fit(X_train,y_train)
    
    
#calculate accuracy
predict_train = model.predict(X_train)
predict_val = model.predict(X_val)
accuracy_train = accuracy_score(y_train,predict_train)
print("Accuracies")
print('accuracy_score on train dataset : ', accuracy_train)
accuracy_val = accuracy_score(y_val,predict_val)
print('accuracy_score on test dataset : ', accuracy_val)
print('\n')
    
    
#calculate feature importances
importances = pd.DataFrame({'feature':X_train.columns,'importance':np.round(model.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False)
print('Importances')
print(importances)
print('\n')
# Out:
#    max_FIT102_Raw_Signal  min_FIT102_Raw_Signal  mean_FIT102_Raw_Signal  \
# 0                   4.30                  -4.28               -0.248235
# 1                   4.58                  -3.32                0.001176
# 2                   5.10                  -3.80                0.071765
# 3                   5.10                  -3.80               -0.042353
# 4                   5.10                  -3.80                0.175294
#
#    std_FIT102_Raw_Signal  max_FIT202_Raw_Signal  min_FIT202_Raw_Signal  \
# 0               2.485488                   2.68                  -4.32
# 1               2.543123                   2.26                  -5.88
# 2               2.814365                   5.16                  -5.88
# 3               2.228765                   5.16                  -5.88
# 4               2.095346                   2.74                  -3.54
#
#    mean_FIT202_Raw_Signal  std_FIT202_Raw_Signal  max_LIT101_Raw_Signal  \
# 0               -0.040000               1.948820                   2.50
# 1               -0.301176               2.072203                   2.56
# 2               -0.015294               2.419654                   2.56
# 3                0.134118               2.475508                   1.86
# 4               -0.143529               1.719989                   1.86
#
#    min_LIT101_Raw_Signal  mean_LIT101_Raw_Signal  std_LIT101_Raw_Signal  \
# 0                  -2.28               -0.052941               1.501149
# 1                  -2.54               -0.140000               1.460856
# 2                  -2.54               -0.109412               1.563699
# 3                  -2.54               -0.074118               1.471713
# 4                  -1.64               -0.080000               1.341343
#
#    max_LIT201_Raw_Signal  min_LIT201_Raw_Signal  mean_LIT201_Raw_Signal  \
# 0                   0.32                  -0.32               -0.032941
# 1                   0.38                  -0.32                0.014118
# 2                   0.38                  -0.32                0.031765
# 3                   0.38                  -0.50               -0.005882
# 4                   0.34                  -0.50                0.012941
#
#    std_LIT201_Raw_Signal  max_PIT101_Raw_Signal  min_PIT101_Raw_Signal  \
# 0               0.235366                   0.10                  -0.18
# 1               0.248572                   0.18                  -0.18
# 2               0.237703                   0.18                  -0.16
# 3               0.223357                   0.18                  -0.16
# 4               0.201115                   0.16                  -0.12
#
#    mean_PIT101_Raw_Signal  std_PIT101_Raw_Signal  max_PIT102_Raw_Signal  \
# 0                0.001471               0.077938                   1.04
# 1                0.002353               0.093777                   0.76
# 2               -0.007059               0.072091                   0.76
# 3               -0.001765               0.087195                   0.68
# 4                0.004706               0.078908                   3.44
#
#    min_PIT102_Raw_Signal  mean_PIT102_Raw_Signal  std_PIT102_Raw_Signal  \
# 0                  -1.00           -2.612289e-17               0.648151
# 1                  -1.00           -1.764706e-02               0.500843
# 2                  -1.18           -2.941176e-02               0.583186
# 3                  -1.18            1.176471e-02               0.474608
# 4                  -1.18            2.141176e-01               0.952070
#
#    max_PIT201_Raw_Signal  min_PIT201_Raw_Signal  mean_PIT201_Raw_Signal  \
# 0                   0.36                  -0.80               -0.020000
# 1                   0.32                  -0.52               -0.001176
# 2                   0.30                  -0.40                0.004706
# 3                   0.30                  -0.40               -0.005882
# 4                   0.60                  -0.46               -0.008235
#
#    std_PIT201_Raw_Signal  max_PIT202_Raw_Signal  min_PIT202_Raw_Signal  \
# 0               0.320624                   0.44                  -0.46
# 1               0.270414                   0.60                  -0.68
# 2               0.209944                   0.60                  -0.68
# 3               0.227130                   0.60                  -0.68
# 4               0.258849                   0.58                  -0.90
#
#    mean_PIT202_Raw_Signal  std_PIT202_Raw_Signal  max_SI102_Raw_Signal  \
# 0                0.008235               0.281164                  4.60
# 1                0.010588               0.337870                  4.60
# 2               -0.031765               0.301169                  4.52
# 3               -0.003529               0.346355                  3.32
# 4                0.010588               0.390904                  2.88
#
#    min_SI102_Raw_Signal  mean_SI102_Raw_Signal  std_SI102_Raw_Signal  \
# 0                 -5.52               0.095882              3.510354
# 1                 -5.52              -0.005882              2.935633
# 2                 -7.34              -0.094118              3.015840
# 3                 -7.34               0.090980              2.360724
# 4                 -7.34              -0.021176              2.296775
#
#    max_SI202_Raw_Signal  min_SI202_Raw_Signal  mean_SI202_Raw_Signal  \
# 0                  3.36                 -3.78               0.144706
# 1                  5.50                 -4.86               0.216471
# 2                  5.50                 -4.86               0.003529
# 3                  5.50                 -4.86               0.007059
# 4                  4.10                 -4.10              -0.045882
#
#    std_SI202_Raw_Signal  na_FIT102_Raw_Signal  na_FIT202_Raw_Signal  \
# 0              2.021256                     0                     0
# 1              2.585239                     0                     0
# 2              2.354902                     0                     0
# 3              2.695959                     0                     0
# 4              2.096411                     0                     0
#
#    na_LIT101_Raw_Signal  na_LIT201_Raw_Signal  na_PIT101_Raw_Signal  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    na_PIT102_Raw_Signal  na_PIT201_Raw_Signal  na_PIT202_Raw_Signal  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    na_SI102_Raw_Signal  na_SI202_Raw_Signal  bin_anomaly
# 0                    0                    0            0
# 1                    0                    0            0
# 2                    0                    0            0
# 3                    0                    0            0
# 4                    0                    0            0
# Accuracies
# accuracy_score on train dataset :  1.0
# accuracy_score on test dataset :  0.9261363636363636
#
#
# Importances
#                    feature  importance
# 18  mean_PIT101_Raw_Signal       0.086
# 14  mean_LIT201_Raw_Signal       0.072
# 10  mean_LIT101_Raw_Signal       0.057
# 13   min_LIT201_Raw_Signal       0.042
# 28   max_PIT202_Raw_Signal       0.037
# 27   std_PIT201_Raw_Signal       0.036
# 24   max_PIT201_Raw_Signal       0.035
# 31   std_PIT202_Raw_Signal       0.034
# 15   std_LIT201_Raw_Signal       0.034
# 12   max_LIT201_Raw_Signal       0.031
# 1    min_FIT102_Raw_Signal       0.030
# 3    std_FIT102_Raw_Signal       0.030
# 39    std_SI202_Raw_Signal       0.029
# 5    min_FIT202_Raw_Signal       0.024
# 29   min_PIT202_Raw_Signal       0.024
# 37    min_SI202_Raw_Signal       0.023
# 7    std_FIT202_Raw_Signal       0.020
# 35    std_SI102_Raw_Signal       0.019
# 16   max_PIT101_Raw_Signal       0.019
# 6   mean_FIT202_Raw_Signal       0.018
# 26  mean_PIT201_Raw_Signal       0.018
# 25   min_PIT201_Raw_Signal       0.018
# 36    max_SI202_Raw_Signal       0.016
# 0    max_FIT102_Raw_Signal       0.016
# 23   std_PIT102_Raw_Signal       0.015
# 19   std_PIT101_Raw_Signal       0.015
# 32    max_SI102_Raw_Signal       0.015
# 4    max_FIT202_Raw_Signal       0.015
# 17   min_PIT101_Raw_Signal       0.014
# 33    min_SI102_Raw_Signal       0.014
# 9    min_LIT101_Raw_Signal       0.014
# 2   mean_FIT102_Raw_Signal       0.013
# 47    na_PIT202_Raw_Signal       0.013
# 11   std_LIT101_Raw_Signal       0.013
# 34   mean_SI102_Raw_Signal       0.013
# 8    max_LIT101_Raw_Signal       0.012
# 20   max_PIT102_Raw_Signal       0.012
# 38   mean_SI202_Raw_Signal       0.011
# 21   min_PIT102_Raw_Signal       0.011
# 22  mean_PIT102_Raw_Signal       0.010
# 30  mean_PIT202_Raw_Signal       0.010
# 44    na_PIT101_Raw_Signal       0.005
# 42    na_LIT101_Raw_Signal       0.003
# 46    na_PIT201_Raw_Signal       0.002
# 49     na_SI202_Raw_Signal       0.002
# 40    na_FIT102_Raw_Signal       0.001
# 43    na_LIT201_Raw_Signal       0.001
# 48     na_SI102_Raw_Signal       0.001
# 41    na_FIT202_Raw_Signal       0.000
# 45    na_PIT102_Raw_Signal       0.000

# %%
model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 100,
#  'verbose': 0,
#  'warm_start': False}

# %%
#model hypertuning

# Number of trees in random forest
n_estimators = [50,75,100]

# Number of features to consider at every split; REMEMBER TO CHANGE THIS WHEN MORE FEATURES ARE PRESENT
max_features = [1,2,5,10,12,15,20]

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 20, 50]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Create the grid
search_params = {'n_estimators': n_estimators,
                 'max_features': max_features,
                 'min_samples_split': min_samples_split,
                 'bootstrap': bootstrap}

cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=100)

#perform model hypertuning

model_v2 = GridSearchCV(model, search_params, cv=cv, n_jobs=-1)

model_v2.fit(X_train, y_train)

best_params = model_v2.best_params_

print('Best Parameters: ', model_v2.best_params_)

print('Best score: ', model_v2.best_score_)
# Out:
# Best Parameters:  {'bootstrap': False, 'max_features': 5, 'min_samples_split': 2, 'n_estimators': 75}
# Best score:  0.9807032967032967

# %%
print(y_val.unique())
# Out:
# [0 1]

# %%
#train the hypetuned model

model_v3 = RandomForestClassifier(random_state = 100, bootstrap = 'False', min_samples_split=2, max_features=5, n_estimators = 75)
model_v3.fit(X_train, y_train)

#perform cross validation
cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=100)
scores = cross_val_score(model_v3, X, y, cv=cv, n_jobs=-1)
 
print('Cross Validation accuracy scores: %s' % scores)
 
print('Cross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores),np.std(scores)))
# Out:
# Cross Validation accuracy scores: [0.97802198 0.97538462 0.97274725 0.97846154 0.96879121 0.97450549
#  0.97318681 0.97626374 0.97802198 0.97406593]
# Cross Validation accuracy: 0.975 +/- 0.003

# %%
#perform cross validation
cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=100)
scores = cross_val_score(model_v3, X, y, cv=cv, n_jobs=-1, scoring=make_scorer(cedric_metric_binary, greater_is_better=True))
 
print('Cross Validation accuracy scores: %s' % scores)
 
print('Cross Validation accuracy: %.3f +/- %.3f' % (np.mean(scores),np.std(scores)))
# Out:
# Cross Validation accuracy scores: [2.63292475e-20 2.18588472e-24 1.51702545e-27 1.43315039e-21
#  1.69145772e-27 3.96395310e-29 7.84703088e-26 5.57432796e-24
#  2.07472908e-22 9.53810566e-28]
# Cross Validation accuracy: 0.000 +/- 0.000

# %%
#calculate feature importances
importances = pd.DataFrame({'feature':X_train.columns,'importance':np.round(model_v3.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False)
print('Importances')
print(importances)
print('\n')  
    
#print classification report
print('Classification report')
predict_val = model_v3.predict(X_val)
print(classification_report(y_val, predict_val))
print('\n')
    
#print normalized confusion matrix   
matrix = plot_confusion_matrix(model_v3, X_val, y_val, cmap=plt.cm.Blues, normalize='true')
matrix.ax_.set_title('Confusion Matrix')
fig = plt.gcf()
fig.set_size_inches(7, 7)
plt.show()
# Out:
# Importances
#                    feature  importance
# 18  mean_PIT101_Raw_Signal       0.089
# 14  mean_LIT201_Raw_Signal       0.056
# 10  mean_LIT101_Raw_Signal       0.044
# 13   min_LIT201_Raw_Signal       0.039
# 24   max_PIT201_Raw_Signal       0.038
# 12   max_LIT201_Raw_Signal       0.032
# 27   std_PIT201_Raw_Signal       0.031
# 28   max_PIT202_Raw_Signal       0.031
# 15   std_LIT201_Raw_Signal       0.029
# 1    min_FIT102_Raw_Signal       0.029
# 31   std_PIT202_Raw_Signal       0.029
# 7    std_FIT202_Raw_Signal       0.027
# 3    std_FIT102_Raw_Signal       0.026
# 39    std_SI202_Raw_Signal       0.026
# 29   min_PIT202_Raw_Signal       0.024
# 5    min_FIT202_Raw_Signal       0.024
# 37    min_SI202_Raw_Signal       0.024
# 26  mean_PIT201_Raw_Signal       0.024
# 36    max_SI202_Raw_Signal       0.022
# 16   max_PIT101_Raw_Signal       0.021
# 0    max_FIT102_Raw_Signal       0.021
# 25   min_PIT201_Raw_Signal       0.020
# 6   mean_FIT202_Raw_Signal       0.020
# 33    min_SI102_Raw_Signal       0.018
# 35    std_SI102_Raw_Signal       0.018
# 23   std_PIT102_Raw_Signal       0.017
# 4    max_FIT202_Raw_Signal       0.017
# 19   std_PIT101_Raw_Signal       0.016
# 17   min_PIT101_Raw_Signal       0.016
# 34   mean_SI102_Raw_Signal       0.016
# 38   mean_SI202_Raw_Signal       0.014
# 9    min_LIT101_Raw_Signal       0.014
# 2   mean_FIT102_Raw_Signal       0.014
# 32    max_SI102_Raw_Signal       0.014
# 20   max_PIT102_Raw_Signal       0.013
# 8    max_LIT101_Raw_Signal       0.013
# 21   min_PIT102_Raw_Signal       0.012
# 47    na_PIT202_Raw_Signal       0.011
# 22  mean_PIT102_Raw_Signal       0.011
# 30  mean_PIT202_Raw_Signal       0.011
# 11   std_LIT101_Raw_Signal       0.011
# 44    na_PIT101_Raw_Signal       0.004
# 42    na_LIT101_Raw_Signal       0.003
# 46    na_PIT201_Raw_Signal       0.003
# 48     na_SI102_Raw_Signal       0.002
# 49     na_SI202_Raw_Signal       0.002
# 40    na_FIT102_Raw_Signal       0.001
# 43    na_LIT201_Raw_Signal       0.001
# 41    na_FIT202_Raw_Signal       0.000
# 45    na_PIT102_Raw_Signal       0.000
#
#
# Classification report
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94      1156
#            1       0.87      0.92      0.89       604
#
#     accuracy                           0.92      1760
#    macro avg       0.91      0.92      0.92      1760
# weighted avg       0.93      0.92      0.92      1760
